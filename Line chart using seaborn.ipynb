# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\HP\\Downloads\\Salaries.csv')

## hist attribute will remove the background histogram
sns.distplot(df['salary'], bins=10, hist=False)
plt.show()
