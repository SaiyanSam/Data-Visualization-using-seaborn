# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\HP\\Downloads\\country.csv')

## now for bar chart we use countplot method
## we only need to pass column as argument 
## The y-axis will be frequency for column entries
sns.countplot(df['TIME'])
plt.show()
