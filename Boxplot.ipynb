# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\HP\\Downloads\\Salaries.csv')

data = df[(df['salary']>=10000) & df['salary']<=20000]
##creating boxplot using seaborn library
sns.boxplot('discipline', 'salary', data=data)
plt.show()
