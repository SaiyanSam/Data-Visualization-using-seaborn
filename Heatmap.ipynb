# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\HP\\Downloads\\Salaries.csv')

## using df.corr() get the correlation matrix of df dataframe
sns.heatmap(df.corr(), annot=True)
plt.show()
